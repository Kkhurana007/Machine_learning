# %%
import pandas as pd   
import altair as alt

# %% [markdown]
# ### chart docmentation can be studied here https://altair-viz.github.io/user_guide/generated/toplevel/altair.Chart.html

# %% [markdown]
# the questions that arise in our brains motivate us to use the knowledge of data science to testify response-
#  Do cars with big engines use more fuel than cars with small engines? What does the relationship between engine size and fuel efficiency look like? Is it positive? Negative? Linear? Nonlinear? See. they can be dealt with mpg dataframe found in ggplot2

# %%
url = "https://github.com/byuidatascience/data4python4ds/raw/master/data-raw/mpg/mpg.csv"
mpg = pd.read_csv(url)

# %% [markdown]
# ### variables in mpg dataset
#
# 1. displ, a car’s engine size, in litres.
#
# 2. hwy, a car’s fuel efficiency on the highway, in miles per gallon (mpg).
#
#
# now, we keep displ on x-axis and hwy on y-axix

# %%
chart = (alt.Chart(mpg)
  .encode(
    x='displ', 
    y='hwy')
  .mark_circle()
)
chart.mark_point() # data gets represented in the form of points
# Out:
# alt.Chart(...)

# %%
chart.mark_circle() # representation happens in the form of circles
# Out:
# alt.Chart(...)

# %% [markdown]
# ### a graphing template
#
# simply replace the bracketed part with data and provide suitable encodings. further, mark.? enables the representation type for a particular data_type. This will help to create the graphs and plots accordingly.
#
# (alt.Chart(<DATA>)
#    .encode(<ENCODINGS>)
#     <.mark_*()>)

# %%
# answering question number 4 based on text!

chart = (alt.Chart(mpg)
  .encode(
    x='cyl', 
    y='hwy')
  .mark_point()
)

chart.mark_point()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Aesthetic mappings
# if the points, fall outside the linear line, we can change the color of the points to see the trends
#
# This can be done by adding a third variable, like class, to a two dimensional scatterplot by mapping it to an encoding. Trying the code-

# %%
chart = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    color = "class", 
    )
  .mark_circle())


chart.mark_circle()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### let's use class for encoding the size in the same way!

# %%
# second


chart = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    size = "class", 
    )
  .mark_circle())


chart.mark_circle()
# Out:
# alt.Chart(...)

# %%
# third variation (the figures are inbuild); maximum of 8 shapes to be used for one chart


chart = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    shape = "class", 
    )
  .mark_point())


chart.mark_point()
# Out:
# alt.Chart(...)

# %%
# fourth varaition (for a specific color, blue for example)
chart = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    color = alt.value("blue"),  #cusotmizing colors- 
      #https://altair-viz.github.io/user_guide/customization.html#color-schemes
    )
  .mark_circle())


chart.mark_circle()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### to know about data types

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# ### Facets (diving the plots into sub-sets of data)

# %%
chart_f = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
   )
  .mark_circle()
  .facet(
    facet = "class",
    columns = 4
  ))

chart_f.show()
# Out:
# Displaying chart at http://localhost:61144/

# %% [markdown]
# ### Facet being the combination of two variables (column, row)

# %%
chart_f2 = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    )
  .mark_circle()
  .facet(
    column = "drv",
    row = "cyl")
           )
  
chart_f2.show()
#> WARN row encoding should be discrete (ordinal / nominal / binned).
# Out:
# Displaying chart at http://localhost:61741/

# %%
# example code

alt.Chart(mpg).encode(
    x = "displ",
    y = "hwy")
    .mark_circle()
  .facet(column = "drv"))

(alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy"
    )
  .mark_circle()
  .facet(row = "cyl"))
# Out:
#   File <tokenize>:7
#     .facet(column = "drv"))
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
### Geometric plots

# %%
chartp = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy"
    )
  .mark_circle())

chartf = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy"
    )
  .transform_loess("displ", "hwy")
  .mark_line()
  )

chartp.show()  # plot1
# Out:
# Displaying chart at http://localhost:61741/

# %%
chartf.show()  # plot 2
# Out:
# Displaying chart at http://localhost:61741/

# %% [markdown]
#  ### theory
#
#   bar charts use bar marks, line charts use line marks, boxplots use boxplot marks, and so on. Scatterplots break the trend; they use the point mark.
#
#
#  The first plot uses the 'point mark', and the second plot uses the "line mark", a smooth line fitted to the data is calculated using a transformation

# %%
chartl = (alt.Chart(mpg)
  .transform_loess("displ", "hwy", groupby = ["drv"])
  .encode(
    x = "displ",
    y = "hwy",
    strokeDash = "drv"
    )
  .mark_line())
  
chartl.show()
# Out:
# Displaying chart at http://localhost:61741/

# %%
chartleft = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    )
  .transform_loess("displ", "hwy")
  .mark_line())

chartmiddle = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    detail = "drv"
    )
  .transform_loess("displ", "hwy", groupby = ["drv"])
  .mark_line())

chartright = (alt.Chart(mpg)
  .encode(
    x = "displ",
    y = "hwy",
    color=alt.Color("drv", legend=None)
    )
  .transform_loess("displ", "hwy", groupby = ["drv"])
  .mark_line())

chartleft.save('A')
chartmiddle.save('B')
chartright.save('C')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 27
#       9 chartmiddle = (alt.Chart(mpg)
#      10   .encode(
#      11     x = "displ",
#    (...)
#      15   .transform_loess("displ", "hwy", groupby = ["drv"])
#      16   .mark_line())
#      18 chartright = (alt.Chart(mpg)
#      19   .encode(
#      20     x = "displ",
#    (...)
#      24   .transform_loess("displ", "hwy", groupby = ["drv"])
#      25   .mark_line())
# ---> 27 chartleft.save('A')
#      28 chartmiddle.save('B')
#      29 chartright.save('C')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\altair\vegalite\v4\api.py:488, in TopLevelMixin.save(self, fp, format, override_data_transformer, scale_factor, vegalite_version, vega_version, vegaembed_version, **kwargs)
#     486 if override_data_transformer:
#     487     with data_transformers.disable_max_rows():
# --> 488         result = save(**kwds)
#     489 else:
#     490     result = save(**kwds)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\altair\utils\save.py:134, in save(chart, fp, vega_version, vegaembed_version, format, mode, vegalite_version, embed_options, json_kwds, webdriver, scale_factor, **kwargs)
#     132         write_file_or_filename(fp, mimebundle["image/svg+xml"], mode="w")
#     133 else:
# --> 134     raise ValueError("unrecognized format: '{}'".format(format))
#
# ValueError: unrecognized format: 'A'

# %%
from altair_saver import save

save(chart, "chart.vl.json")              # Vega-Lite JSON specification
save(chart, "chart.vg.json")              # Vega JSON specification
save(chart, "chart.html")                 # HTML document
save(chart, "chart.html", inline=True)    # HTML document with all JS code included inline
save(chart, "chart.png")                  # PNG Image
save(chart, "chart.svg")                  # SVG Image
save(chart, "chart.pdf")                  # PDF Image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 from altair_saver import save
# ----> 3 save(chart, "chart.vl.json")              # Vega-Lite JSON specification
#       4 save(chart, "chart.vg.json")              # Vega JSON specification
#       5 save(chart, "chart.html")                 # HTML document
#
# NameError: name 'chart' is not defined

# %%
pip install altair_saver
pip install vl-convert-python
# Out:
#   Cell In[5], line 1
#     pip install altair_saver
#         ^
# SyntaxError: invalid syntax

# %%
pip install altair_saver
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: altair_saver in c:\users\alex\appdata\roaming\python\python310\site-packages (0.5.0)
# Requirement already satisfied: altair in c:\users\alex\appdata\roaming\python\python310\site-packages (from altair_saver) (4.2.2)
# Requirement already satisfied: altair-viewer in c:\users\alex\appdata\roaming\python\python310\site-packages (from altair_saver) (0.4.0)
# Requirement already satisfied: altair-data-server>=0.4.0 in c:\users\alex\appdata\roaming\python\python310\site-packages (from altair_saver) (0.4.1)
# Requirement already satisfied: selenium in c:\users\alex\appdata\roaming\python\python310\site-packages (from altair_saver) (4.8.3)
# Requirement already satisfied: tornado in c:\users\alex\appdata\roaming\python\python310\site-packages (from altair-data-server>=0.4.0->altair_saver) (6.2)
# Requirement already satisfied: portpicker in c:\users\alex\appdata\roaming\python\python310\site-packages (from altair-data-server>=0.4.0->altair_saver) (1.5.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\lib\site-packages (from altair->altair_saver) (4.17.3)
# Requirement already satisfied: pandas>=0.18 in c:\programdata\anaconda3\lib\site-packages (from altair->altair_saver) (1.5.3)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from altair->altair_saver) (0.4)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from altair->altair_saver) (1.23.5)
# Requirement already satisfied: toolz in c:\programdata\anaconda3\lib\site-packages (from altair->altair_saver) (0.12.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from altair->altair_saver) (3.1.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium->altair_saver) (2022.12.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\alex\appdata\roaming\python\python310\site-packages (from selenium->altair_saver) (0.10.2)
# Requirement already satisfied: trio~=0.17 in c:\users\alex\appdata\roaming\python\python310\site-packages (from selenium->altair_saver) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium->altair_saver) (1.26.14)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair->altair_saver) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair->altair_saver) (22.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\alex\appdata\roaming\python\python310\site-packages (from pandas>=0.18->altair->altair_saver) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.18->altair->altair_saver) (2022.7)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium->altair_saver) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium->altair_saver) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium->altair_saver) (3.4)
# Requirement already satisfied: outcome in c:\users\alex\appdata\roaming\python\python310\site-packages (from trio~=0.17->selenium->altair_saver) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\alex\appdata\roaming\python\python310\site-packages (from trio~=0.17->selenium->altair_saver) (1.10)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\alex\appdata\roaming\python\python310\site-packages (from trio~=0.17->selenium->altair_saver) (1.1.1)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium->altair_saver) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\alex\appdata\roaming\python\python310\site-packages (from trio-websocket~=0.9->selenium->altair_saver) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium->altair_saver) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->altair->altair_saver) (2.1.1)
# Requirement already satisfied: psutil in c:\users\alex\appdata\roaming\python\python310\site-packages (from portpicker->altair-data-server>=0.4.0->altair_saver) (5.9.4)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->altair_saver) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\alex\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair->altair_saver) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\alex\appdata\roaming\python\python310\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->altair_saver) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q altair_saver
